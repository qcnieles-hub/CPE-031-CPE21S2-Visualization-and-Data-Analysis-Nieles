# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/CPE-031-CPE21S2-Visualization-and-Data-Analysis-Nieles/blob/main/CPE_009B_Nieles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Account.py

# %%
# Create the Account class
class Account:
    # Constructor function to initialize the account information
    def __init__(self, account_number, account_firstname, account_lastname, current_balance,
                 address, email):
        self.account_number = account_number
        self.account_firstname = account_firstname
        self.account_lastname = account_lastname
        self.current_balance = current_balance
        self.address = address
        self.email = email
    # Function to update the account address
    def update_address(self, new_address):
        self.address = new_address
    # Function to update the account email
    def update_email(self, new_email):
        self.email = new_email

# %% [markdown]
# ATM.py

# %%
# Create the ATM class
class ATM:
    # Constructor function to initialize the ATM serial number
    def __init__(self, serial_number):
        self.serial_number = serial_number
        self.summary = ""

    # Function for depositing money
    def deposit(self, account, amount):
        account.current_balance = account.current_balance + amount
        self.summary = self.summary + "Deposit money\n"
        print("Deposit Complete")

    # Function for withdrawing money
    def withdraw(self, account, amount):
        if account.current_balance >= amount:
            account.current_balance = account.current_balance - amount
            self.summary = self.summary + "Withdraw money\n"
            print("Withdraw Complete")
        else:
            print("Insufficient Balance")

    # Function to check the current balance
    def check_currentbalance(self, account):
        print("Current Balance:", account.current_balance)

    # Function to view the transaction summary
    def view_transactionsummary(self):
        print("Transaction Summary:")
        print(self.summary)

# %%
# Create the first account
Account1 = Account(
1001,
"Juanito Akari",
"AKari",
5000,
"Philippines",
"Akarigmail.com"
)
# Create the second account
Account2 = Account(
1002,
"Juan",
"Dela Cruz",
3000,
"Philippines",
"juan@gmail.com"
)
# Create the ATM object
atm = ATM(123456)
# Display the first account information
print("Account 1 Name:", Account1.account_firstname, Account1.account_lastname)
print("Account 1 Balance:", Account1.current_balance)
# Display the ATM serial number
print("ATM Serial Number:", atm.serial_number)
# Deposit money into Account 1
atm.deposit(Account1, 1000)
# Withdraw money from Account 1
atm.withdraw(Account1, 500)
# Check the current balance
atm.check_currentbalance(Account1)
# Display the transaction summary
atm.view_transactionsummary()
# Update the account address
Account1.update_address("Manila, Philippines")

# Update the account email
Account1.update_email("Elliot@gmail.com")
# Display the updated information
print("Updated Address:", Account1.address)
print("Updated Email:", Account1.email)
# Out:
# Account 1 Name: Juanito Akari AKari
# Account 1 Balance: 5000
# ATM Serial Number: 123456
# Deposit Complete
# Withdraw Complete
# Current Balance: 5500
# Transaction Summary:
# Deposit money
# Withdraw money
#
# Updated Address: Manila, Philippines
# Updated Email: Elliot@gmail.com
